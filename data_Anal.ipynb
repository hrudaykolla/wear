# %%
import pandas as pd
# raw
wear_Data = pd.read_csv("./data/wear/raw/inertial/sbj_2.csv")
wear_Data.describe()
# Out:
#          sbj_id  right_arm_acc_x  right_arm_acc_y  right_arm_acc_z  \
# count  178200.0    178200.000000    178200.000000    178200.000000
# mean        2.0        -0.488362         0.344387        -0.242142
# std         0.0         0.657444         0.655877         0.465139
# min         2.0        -7.981970        -2.927504        -3.605127
# 25%         2.0        -0.909934        -0.014299        -0.567530
# 50%         2.0        -0.586854         0.278562        -0.211855
# 75%         2.0        -0.072373         0.650521         0.017044
# max         2.0         6.808211         6.079098         2.961261
#
#        right_leg_acc_x  right_leg_acc_y  right_leg_acc_z  left_leg_acc_x  \
# count    178200.000000    178200.000000    178200.000000   178200.000000
# mean          0.885337        -0.008535         0.125758        0.860646
# std           0.693255         0.824313         0.456775        0.663379
# ...

# %%
import pandas as pd
import numpy as np

#i3d
wear_Data = np.load('./data/wear/processed/i3d_features/30_frames_15_stride/sbj_0.npy')
wear_Data_pd = pd.DataFrame(wear_Data)
wear_Data_pd.describe()
# Out:
#                0             1             2             3             4     \
# count  11176.000000  11176.000000  11176.000000  11176.000000  11176.000000
# mean       0.081917      0.054967      0.183479      0.109350      0.376176
# std        0.073804      0.055571      0.144616      0.110821      0.264215
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.029591      0.015706      0.073821      0.029916      0.175661
# 50%        0.059536      0.036156      0.150320      0.071397      0.299660
# 75%        0.110032      0.077164      0.256287      0.154163      0.520289
# max        0.499797      0.458630      1.028594      0.845074      1.405433
#
#                5             6             7             8             9     \
# count  11176.000000  11176.000000  11176.000000  11176.000000  11176.000000
# mean       0.111697      0.104428      0.174687      0.043346      0.243612
# ...

# %%
#lstm
wear_Data = np.load('./data/wear/lstm_processed/inertial_features/60_frames_30_stride/wear_split_1/sbj_0.npy')
wear_Data_pd = pd.DataFrame(wear_Data)
wear_Data_pd.describe()
# Out:
#               0            1            2            3            4     \
# count  5587.000000  5587.000000  5587.000000  5587.000000  5587.000000
# mean     -0.110827     0.128740     0.048945     0.285243    -0.128236
# std       0.345426     0.540330     0.456313     0.561832     0.713951
# min      -0.999733    -0.947432    -0.999992    -0.999999    -0.999996
# 25%      -0.198381    -0.353193    -0.070960    -0.012179    -0.855241
# 50%      -0.007914     0.200325     0.017710     0.151828    -0.096654
# 75%       0.001558     0.632374     0.261244     0.877623     0.571003
# max       0.999977     0.992825     1.000000     1.000000     0.999999
#
#               5            6            7            8            9     ...  \
# count  5587.000000  5587.000000  5587.000000  5587.000000  5587.000000  ...
# mean     -0.139876    -0.169247    -0.016693     0.181414    -0.068979  ...
# std       0.536237     0.665842     0.539141     0.537712     0.519578  ...
# ...
